# %% [markdown]
# ##                                                        Problem Definition
#
# ## The goal of this project is to build a machine learning model that predicts whether a person is at risk of cardiovascular (heart) disease.
# ## The model uses patient medical information such as age, gender, height, weight, cholesterol level, blood pressure, and lifestyle factors.

# %% [markdown]
# ## 1. Importing all the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Load the dataset

# %%
df = pd.read_csv("cardio_train.csv",sep=";")
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %% [markdown]
# ## 3. basic information of dataset

# %%
df.shape
# Out:
# (70000, 13)

# %%
len(df)
# Out:
# 70000

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %% [markdown]
# ####  Dataset structure + datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %% [markdown]
# ####  How many Columns

# %%
df.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %% [markdown]
# ####  Datatypes of all Columns

# %%
df.dtypes
# Out:
# id               int64
# age              int64
# gender           int64
# height           int64
# weight         float64
# ap_hi            int64
# ap_lo            int64
# cholesterol      int64
# gluc             int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# dtype: object

# %% [markdown]
# #### Statistical summary

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %% [markdown]
# #### Check Missing value

# %%
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %% [markdown]
# #### Get Single value and full raw

# %%
print(df.loc[0,'age'])
print(df.loc[0])
# Out:
# 18393
# id                 0.0
# age            18393.0
# gender             2.0
# height           168.0
# weight            62.0
# ap_hi            110.0
# ap_lo             80.0
# cholesterol        1.0
# gluc               1.0
# smoke              0.0
# alco               0.0
# active             1.0
# cardio             0.0
# Name: 0, dtype: float64

# %%
df.loc[0:5, ['age', 'weight', 'height']]
# Out:
#      age  weight  height
# 0  18393    62.0     168
# 1  20228    85.0     156
# 2  18857    64.0     165
# 3  17623    82.0     169
# 4  17474    56.0     156
# 5  21914    67.0     151

# %%
df.iloc[0,5]
# Out:
# 110

# %% [markdown]
# #### count unique value of specific column

# %%
print(df['age'].nunique())
# Out:
# 8076

# %%
df['age'].unique()
# Out:
# array([18393, 20228, 18857, ..., 14925, 17727, 17926], dtype=int64)

# %%
print(df['age'].sum()-df['age'].nunique())
# print(df.duplicate('age').sum())
# Out:
# 1362812531

# %% [markdown]
# #### Total Duplicate record

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Mean of age

# %%
print(np.mean(df['age']))
print(df['age'].sum()/len(df))
# Out:
# 19468.865814285713
# 19468.865814285713

# %% [markdown]
# #### Max & Min Blood Pressure

# %%
np.max(df['ap_hi']), np.min(df['ap_lo'])
# Out:
# (16020, -70)

# %% [markdown]
# #### Count of Heart Disease Classes

# %%
df['cardio'].value_counts()
# Out:
# cardio
# 0    35021
# 1    34979
# Name: count, dtype: int64

# %%
df["age_year"]=(df['age']/365).astype(int)
df["age_year"]
# Out:
# 0        50
# 1        55
# 2        51
# 3        48
# 4        47
#          ..
# 69995    52
# 69996    61
# 69997    52
# 69998    61
# 69999    56
# Name: age_year, Length: 70000, dtype: int32

# %% [markdown]
# ####  Histogram (Age)

# %%
plt.hist(df['age_year'], bins=20,color='lightblue', edgecolor='white')
plt.title("Age Distribution")
plt.show()

# %% [markdown]
# #### Target variable bar chat

# %%
df['cholesterol'].value_counts().plot(kind='bar')
plt.title("Heart Disease Distribution")
plt.show()

# %% [markdown]
# #### Blood Pressure Scatter Plot

# %%
plt.scatter(df['ap_hi'], df['ap_lo'],alpha=0.4)
plt.xlabel("Systolic BP")
plt.ylabel("Diastolic BP")
plt.show()

# %% [markdown]
# #### Gender vs Disease

# %%
pd.crosstab(df['gender'], df['cardio']).plot(kind='bar')
plt.show()

# %% [markdown]
# #### Boxplot for Weight

# %%
plt.boxplot(df['weight'])
plt.show()

# %% [markdown]
# #### Correlation matrix

# %%
arr=df.corr(numeric_only=True)
arr
# Out:
#                    id       age    gender    height    weight     ap_hi  \
# id           1.000000  0.003457  0.003502 -0.003038 -0.001830  0.003356
# age          0.003457  1.000000 -0.022811 -0.081515  0.053684  0.020764
# gender       0.003502 -0.022811  1.000000  0.499033  0.155406  0.006005
# height      -0.003038 -0.081515  0.499033  1.000000  0.290968  0.005488
# weight      -0.001830  0.053684  0.155406  0.290968  1.000000  0.030702
# ap_hi        0.003356  0.020764  0.006005  0.005488  0.030702  1.000000
# ap_lo       -0.002529  0.017647  0.015254  0.006150  0.043710  0.016086
# cholesterol  0.006106  0.154424 -0.035821 -0.050226  0.141768  0.023778
# gluc         0.002467  0.098703 -0.020491 -0.018595  0.106857  0.011841
# smoke       -0.003699 -0.047633  0.338135  0.187989  0.067780 -0.000922
# alco         0.001210 -0.029723  0.170966  0.094419  0.067113  0.001408
# active       0.003755 -0.009927  0.005866 -0.006570 -0.016867 -0.000033
# ...

# %% [markdown]
# #### Heatmap

# %%
sns.heatmap(arr)
plt.show()
